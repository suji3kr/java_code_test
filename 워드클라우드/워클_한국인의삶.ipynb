# %%
#240805 cmd  java -version /자바버전  확인
#>/자바라이브러리 깔기 
#cmd
#pip install jpype1  
#pip install konlpy 

#1.데이터 분석
moon = open('oecd삶의만족도.txt',encoding= 'utf-8').read()
moon
# Out:
# '“한국인 삶 만족도, OECD 38개국 중 36위”\n최지은 기자\n입력 2023.02.20.\n16:50\u3000\n \n \n \n우리나라 국민의 삶에 대한 만족도가 경제협력개발기구(OECD) 국가 중 최하위권인 것으로 나타났다.\n\n통계청이 20일 발표한 ‘국민 삶의 질 2022’ 보고서에 따르면, 우리나라 국민의 삶에 대한 평가 점수는 2019~2021년 기준 평균 10점 만점에 5.9점이었다.\n\n\nOECD 38개국 중 36위에 해당하는 점수이며 OECD 평균(6.7점)보다는 0.8점 낮았다. 우리나라보다 점수가 낮은 국가는 튀르키예(4.7점)와 콜롬비아(5.8점)뿐이었다. 핀란드(7.8점), 덴마크(7.6점), 스위스(7.5점) 등 북유럽 국가가 최상위권을 차지했다.\n\n삶의 만족도는 가구소득이 증가할수록 높아졌다. 월 소득이 100만원 미만인 저소득층의 삶의 만족도는 5.5점에 그쳤다. 100만원 이상~200만원 미만 계층은 6.0점으로 0.5점 더 높았고, 500만원 이상은 6.5점으로 100만원 미만 계층에 비해 1점 더 높았다.\n\n자살률도 전년 대비 증가했다. 2021년 기준 자살 인구는 10만명당 26명으로, 전년대비 0.3명 늘었다. 남성은 연령이 증가할수록 자살률이 높았고, 여성은 70세 이상을 제외하면 20~30대의 자살률이 높게 나타났다. 다만 2020년과 비교하면 10대와 20대에서 남녀 모두 자살률이 증가했다. 다른 나라와 비교해도 우리나라 자살률은 월등히 높은 편이다. 2019년 기준으로 비교했을 때, 10만명당 25.4명으로 OECD 국가 중 가장 높다.\n\n상대적 빈곤율은 15.3%로, OECD 국가 중 31위를 차지했다. 상대적 빈곤율이란 중위소득 50% 이하에 해당하는 계층이다. 빈곤율이 높을수록 저소득층 규모가 큰 것으로 해석한다. 우리나라 상대적 빈곤율은 일본(15.7%)에 비해서는 낮지만 호주(12.6%), 영국(11.2%), 독일(10.9%), 프랑스(8.4%) 등 주요국에 비해서는 높았다. 66세 이상 인구의 상대적 빈곤율은 40.4%로 OECD 국가 중 최상위권을 차지했다.\n\n대인신뢰도는 2021년 59.3%로 전년대비 8.7%p 증가했다. 대인신뢰도는 자신과 친밀한 사람이 외에 다른 사람들까지 신뢰하는 인구의 비율을 뜻한다. 대인신뢰도는 2014년 73.3%를 기록한 뒤 이듬해 66.2%로 하락한 후 소폭 증감을 반복하다가, 2020년 50.6%로 크게 떨어졌다. 통계청은 “2020년 코로나19 확산으로 인한 거리두기 일상화와, 타인으로부터 바이러스가 전염될 수 있다는 두려움이 대인신뢰도를 낮추는 데 영향을 미쳤을 수 있다”며 “2021년에도 코로나19가 이어지기는 했지만, 대인신뢰도는 어느 정도 회복됐다”고 설명했다.\n\n최지은 기자 bloomy@chosun.com'

# %%
#불필요한 문자제거  (regular expression :정규화표현식 )
#한글이 아니면 공백으로 처리 
import re
moon = re.sub('[^가-힣]',' ',moon)
moon
# Out:
# ' 한국인 삶 만족도         개국 중   위  최지은 기자 입력                          우리나라 국민의 삶에 대한 만족도가 경제협력개발기구       국가 중 최하위권인 것으로 나타났다   통계청이   일 발표한  국민 삶의 질       보고서에 따르면  우리나라 국민의 삶에 대한 평가 점수는          년 기준 평균   점 만점에    점이었다           개국 중   위에 해당하는 점수이며      평균    점 보다는    점 낮았다  우리나라보다 점수가 낮은 국가는 튀르키예    점 와 콜롬비아    점 뿐이었다  핀란드    점   덴마크    점   스위스    점  등 북유럽 국가가 최상위권을 차지했다   삶의 만족도는 가구소득이 증가할수록 높아졌다  월 소득이    만원 미만인 저소득층의 삶의 만족도는    점에 그쳤다     만원 이상    만원 미만 계층은    점으로    점 더 높았고     만원 이상은    점으로    만원 미만 계층에 비해  점 더 높았다   자살률도 전년 대비 증가했다      년 기준 자살 인구는   만명당   명으로  전년대비    명 늘었다  남성은 연령이 증가할수록 자살률이 높았고  여성은   세 이상을 제외하면      대의 자살률이 높게 나타났다  다만     년과 비교하면   대와   대에서 남녀 모두 자살률이 증가했다  다른 나라와 비교해도 우리나라 자살률은 월등히 높은 편이다      년 기준으로 비교했을 때    만명당     명으로      국가 중 가장 높다   상대적 빈곤율은      로       국가 중   위를 차지했다  상대적 빈곤율이란 중위소득     이하에 해당하는 계층이다  빈곤율이 높을수록 저소득층 규모가 큰 것으로 해석한다  우리나라 상대적 빈곤율은 일본       에 비해서는 낮지만 호주         영국         독일         프랑스       등 주요국에 비해서는 높았다    세 이상 인구의 상대적 빈곤율은      로      국가 중 최상위권을 차지했다   대인신뢰도는     년      로 전년대비       증가했다  대인신뢰도는 자신과 친밀한 사람이 외에 다른 사람들까지 신뢰하는 인구의 비율을 뜻한다  대인신뢰도는     년      를 기록한 뒤 이듬해      로 하락한 후 소폭 증감을 반복하다가      년      로 크게 떨어졌다  통계청은      년 코로나   확산으로 인한 거리두기 일상화와  타인으로부터 바이러스가 전염될 수 있다는 두려움이 대인신뢰도를 낮추는 데 영향을 미쳤을 수 있다 며      년에도 코로나  가 이어지기는 했지만  대인신뢰도는 어느 정도 회복됐다 고 설명했다   최지은 기자                  '

# %%
# hannanum 만들기 -> 명사 추출 
import konlpy
hannanum = konlpy.tag.Hannanum()

# %%
#연설문에서 명사 추출
nouns = hannanum.nouns(moon) 
nouns
# Out:
# ['한국인',
#  '삶',
#  '만족',
#  '개국',
#  '중',
#  '위',
#  '최',
#  '기',
#  '입력',
#  '우리나라',
#  '국민',
#  '삶',
#  '만족도',
#  '경제협력개발기구',
#  '국',
#  '중',
#  '최하위권',
#  '것',
#  '통계청',
#  '일',
#  '발표',
#  '국민',
#  '삶',
#  '보고서',
#  '우리나라',
#  '국민',
#  '삶',
#  '평',
#  '점수',
#  '년',
#  '기준',
#  '평균',
#  '점',
#  '만점',
#  '점',
#  '개국',
#  '중',
#  '위',
#  '해당',
#  '점수',
#  '평균',
#  '점',
#  '점',
#  '우리나라',
#  '점수',
#  '국가',
#  '튀르키예',
#  '점',
#  '콜롬비아',
#  '점',
#  '뿐',
#  '핀란드',
#  '점',
#  '덴마크',
#  '점',
#  '스위스',
#  '점',
#  '등',
#  '북유럽',
#  '국가',
#  '최상위권',
#  '삶',
#  '만족',
#  '가구소득',
#  '증가',
#  '월',
#  '소득',
#  '만원',
#  '미만',
#  '저소득층',
#  '삶',
#  '만족',
#  '점',
#  '만원',
#  '이상',
#  '만원',
#  '미',
#  '계층',
#  '점',
#  '점',
#  '만원',
#  '이상',
#  '점',
#  '만원',
#  '미',
#  '계층',
#  '점',
#  '자살률',
#  '전년',
#  '대비',
#  '증가',
#  '년',
#  '기준',
#  '자살',
#  '인구',
#  '만명당',
#  '명',
#  '전년대비',
#  '명',
#  '남성',
#  '연령',
#  '증가',
#  '자살률',
#  '여성',
#  '세',
#  '이상',
#  '제외',
#  '대',
#  '자살률',
#  '년',
#  '비교',
#  '대',
#  '대',
#  '남녀',
#  '자살률',
#  '증가',
#  '나라',
#  '비교해',
#  '우리나라',
#  '자살률',
#  '편',
#  '년',
#  '기준',
#  '비교',
#  '때',
#  '만명당',
#  '명',
#  '국',
#  '중',
#  '상대적',
#  '빈곤율',
#  '로',
#  '국',
#  '중',
#  '위',
#  '상대적',
#  '빈곤율',
#  '중위소득',
#  '이하',
#  '해당',
#  '계층',
#  '빈곤율',
#  '저소득층',
#  '규모',
#  '것',
#  '해석',
#  '우리나라',
#  '상대적',
#  '빈곤율',
#  '일본',
#  '호주',
#  '영국',
#  '독',
#  '프랑스',
#  '등',
#  '주요국',
#  '세',
#  '이상',
#  '인구',
#  '상대적',
#  '빈곤율',
#  '로',
#  '국',
#  '중',
#  '최상위권',
#  '대인신뢰도',
#  '년',
#  '로',
#  '전년대비',
#  '증가',
#  '대인신뢰도',
#  '자신',
#  '친밀한',
#  '사람',
#  '외',
#  '사람들',
#  '신뢰',
#  '인구',
#  '비율',
#  '뜻',
#  '대인신뢰도',
#  '년',
#  '를',
#  '기록',
#  '뒤',
#  '이듬해',
#  '로',
#  '하락',
#  '후',
#  '소폭',
#  '증감',
#  '반복',
#  '년',
#  '로',
#  '통계청',
#  '년',
#  '코',
#  '확산',
#  '거리두',
#  '일상화',
#  '타인',
#  '바이러스',
#  '전염',
#  '수',
#  '두려움',
#  '대인신뢰도',
#  '데',
#  '영향',
#  '수',
#  '며',
#  '년',
#  '코',
#  '대인신뢰도',
#  '정도',
#  '회복',
#  '설명',
#  '최',
#  '기자']

# %%
#데이터 프레임으로 변환 
import pandas as pd
df_word = pd.DataFrame({'word': nouns})
df_word
# Out:
#     word
# 0    한국인
# 1      삶
# 2     만족
# 3     개국
# 4      중
# ..   ...
# 213   정도
# 214   회복
# 215   설명
# 216    최
# 217   기자
#
# [218 rows x 1 columns]

# %%
# 글자수 열 추가
df_word['count']= df_word['word'].str.len()
df_word
# Out:
#     word  count
# 0    한국인      3
# 1      삶      1
# 2     만족      2
# 3     개국      2
# 4      중      1
# ..   ...    ...
# 213   정도      2
# 214   회복      2
# 215   설명      2
# 216    최      1
# 217   기자      2
#
# [218 rows x 2 columns]

# %%
#두글자 이상 단어만 남김 
df_word = df_word.query('count >=2')
df_word.sort_values('count')
# Out:
#          word  count
# 2          만족      2
# 3          개국      2
# 8          입력      2
# 10         국민      2
# 28         점수      2
# ..        ...    ...
# 170     대인신뢰도      5
# 212     대인신뢰도      5
# 180     대인신뢰도      5
# 205     대인신뢰도      5
# 13   경제협력개발기구      8
#
# [136 rows x 2 columns]

# %%
# 단어 빈도 구하기
# 단어별 분리 
# 빈도 구하기
# 내림차순 정렬 
df_word = df_word.groupby('word', as_index = False)\
                 .agg(n = ('word', 'count'))\
                 .sort_values('n',ascending=False)
df_word
# Out:
#      word  n
# 15  대인신뢰도  5
# 19     만원  5
# 45   우리나라  5
# 32    빈곤율  5
# 54    자살률  5
# ..    ... ..
# 78    한국인  1
# 80     해석  1
# 81     호주  1
# 82     확산  1
# 83     회복  1
#
# [84 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams.update({'font.family':'Malgun Gothic', #한글폰트
                    'figure.dpi'  :'120', #해상도 
                    'figure.figsize' :[6.5,6]})

# %%
#단어 빈도 상위 20개 추출
top20 = df_word.head(20)
top20
# Out:
#      word  n
# 15  대인신뢰도  5
# 19     만원  5
# 45   우리나라  5
# 32    빈곤율  5
# 54    자살률  5
# 65     증가  5
# 35    상대적  4
# 47     이상  4
# 10     기준  3
# 21     만족  3
# 6      국민  3
# 60     점수  3
# 49     인구  3
# 4      계층  3
# 5      국가  2
# 18    만명당  2
# 58   전년대비  2
# 67   최상위권  2
# 74     평균  2
# 1      개국  2

# %%
#막대그래프 만들기 
sns.barplot (data =top20, y= 'word',x='n')
# Out:
# <Axes: xlabel='n', ylabel='word'>

# %%
# pip install wordcloud   - cmd 에서 실행

# %%
font = 'malgun.ttf'

# %%
# 데이터 프레임을 딕셔너리로 변환 
dic_word = df_word.set_index('word').to_dict()['n']
#dic_word

# %%
# W C 만들기 (워드클라우드)
from wordcloud import WordCloud
wc = WordCloud (random_state = 1234,                  #난수고정
                font_path = font,                     #폰트설정
                width =400,                           #가로크기
                height =400,                          #세로크기
                background_color = 'white')           #배경색

# %%
# 워드 클라우드 만들기
img_wordcloud = wc.generate_from_frequencies(dic_word)

# 워드 클라우드 출력 #
plt.figure(figsize=(10,10)) # 가로, 세로 크기 설정
plt.axis('off') # 테두리 선 없애기
plt.imshow(img_wordcloud)

# %%
import PIL.Image
import numpy as np

# %%
icon = PIL.Image.open('지도실루엣.png')

# %%
img = PIL.Image.new('RGB', icon.size, (255, 255, 255))
img.paste(icon, icon)
img = np.array(img)

# %%
# wc 만들기
wc = WordCloud(random_state=1234,
               font_path = font,
               width = 400,
               height = 400,
               background_color = 'white',
               mask = img)

# %%
# 워드 클라우드
img_wordcloud = wc.generate_from_frequencies(dic_word)

# 출력
plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(img_wordcloud)
